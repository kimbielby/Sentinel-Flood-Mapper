# %%
from sentinel_flood_mapper import load_config
from sentinel_flood_mapper.pipelines import run_inference_pipeline

# %%
config = load_config("../config/default.yaml")

# %%
pipeline = run_inference_pipeline(
    config=config,
    #image_path=config.paths.inference_examples_dir / "S1Hand" / "Bolivia_23014_S1Hand.tif",
    #label_path=config.paths.inference_examples_dir /"LabelHand" / "Bolivia_23014_LabelHand.tif",
    image_dir=config.paths.inference_examples_dir / "S1Hand",
    label_dir=config.paths.inference_examples_dir / "LabelHand",
    output_dir=config.paths.project_root / "outputs" / "inference",
    #stride=config.inference.stride,
    use_tiling=False,
)
