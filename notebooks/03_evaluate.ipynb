# %%
from sentinel_flood_mapper import load_config
from sentinel_flood_mapper.pipelines import run_evaluation_pipeline

# %%
config = load_config("../config/default.yaml")

# %%
pipeline = run_evaluation_pipeline(config=config)
