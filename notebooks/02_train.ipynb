# %%
from sentinel_flood_mapper import load_config
from sentinel_flood_mapper.pipelines import run_training_pipeline, TrainingPipeline

# %%
config = load_config("../config/default.yaml")

# %%
pipeline = run_training_pipeline(config=config)
# pipeline = TrainingPipeline(config=config)
